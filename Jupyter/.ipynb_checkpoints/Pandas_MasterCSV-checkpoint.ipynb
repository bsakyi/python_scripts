# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   294049  Lightning Charging Cable                1      14.95
# 1   294050          Wired Headphones                1      11.99
# 2   294051      USB-C Charging Cable                2      11.95
# 3   294052          Wired Headphones                1      11.99
# 4   294053          27in FHD Monitor                1     149.99
#
#        Order Date                         Purchase Address
# 0  12/22/19 19:16      939 Odomankuma St, Kumasi, AS 40001
# 1  12/30/19 18:15  116 Kwaku Boateng St, Sunyani, BA 10001
# 2  12/25/19 16:17             924 1st St, Kumasi, AS 40001
# 3  12/24/19 13:15                148 12th St, Wa, UE 48101
# 4  12/06/19 21:21           172 Nii Armah St, Ho, VR 90001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185563 entries, 0 to 185562
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185078 non-null  object
#  1   Product           185078 non-null  object
#  2   Quantity Ordered  185078 non-null  object
#  3   Price Each        185078 non-null  object
#  4   Order Date        185078 non-null  object
#  5   Purchase Address  185078 non-null  object
# dtypes: object(6)
# memory usage: 8.5+ MB

# %%
rows, columns = df.shape
print(f"rows:{rows}  columns:{columns}")
# Out:
# rows:185563  columns:6

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     185078                185078           185078     185078
# unique    177210                    20               11         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         346                 21867           167426      21867
#
#         Order Date  Purchase Address
# count       185078            185078
# unique      141845            140081
# top     Order Date  Purchase Address
# freq           346               346

# %%
# number of nulls
df.isnull().sum()
# Out:
# Order ID            485
# Product             485
# Quantity Ordered    485
# Price Each          485
# Order Date          485
# Purchase Address    485
# dtype: int64

# %%
# drop null values
df.dropna(how = "all", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185078 entries, 0 to 185562
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185078 non-null  object
#  1   Product           185078 non-null  object
#  2   Quantity Ordered  185078 non-null  object
#  3   Price Each        185078 non-null  object
#  4   Order Date        185078 non-null  object
#  5   Purchase Address  185078 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
# the numeric column quantity ordered contains a value which is a string of alphabets 
# df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"])

# %%
df["Quantity Ordered"].unique()
# Out:
# array(['1', '2', '4', '3', 'Quantity Ordered', '5', '6', '7', '8', '10',
#        '9'], dtype=object)

# %%
df = df[df["Quantity Ordered"] != "Quantity Ordered"]

# %%
df["Quantity Ordered"].unique()
# Out:
# array(['1', '2', '4', '3', '5', '6', '7', '8', '10', '9'], dtype=object)

# %%
df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 184732 entries, 0 to 185562
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          184732 non-null  object
#  1   Product           184732 non-null  object
#  2   Quantity Ordered  184732 non-null  int64
#  3   Price Each        184732 non-null  object
#  4   Order Date        184732 non-null  object
#  5   Purchase Address  184732 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 9.9+ MB

# %%
df.describe()
# Out:
#        Quantity Ordered
# count     184732.000000
# mean           1.124813
# std            0.443598
# min            1.000000
# 25%            1.000000
# 50%            1.000000
# 75%            1.000000
# max           10.000000

# %%
df["Quantity Ordered"].mean()
# Out:
# 1.1248132429681919

# %%
df["Quantity Ordered"].min()
# Out:
# 1

# %%
df["Quantity Ordered"].max()
# Out:
# 10

# %%
df["Quantity Ordered"].std()
# Out:
# 0.44359778840488195

# %%
df["Quantity Ordered"].count()
# Out:
# 184732

# %%
df["Price Each"] = pd.to_numeric(df["Price Each"])

# %%
df["Purchase Amount"] = df["Quantity Ordered"] * df["Price Each"]

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df["Year"] = df["Order Date"].dt.year

# %%
df["Month Name"] = df["Order Date"].dt.month_name()

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        294049    Lightning Charging Cable                 1       14.95
# 1        294050            Wired Headphones                 1       11.99
# 2        294051        USB-C Charging Cable                 2       11.95
# 3        294052            Wired Headphones                 1       11.99
# 4        294053            27in FHD Monitor                 1      149.99
# ...         ...                         ...               ...         ...
# 185558   216589  Bose SoundSport Headphones                 1       99.99
# 185559   216590            Wired Headphones                 1       11.99
# 185560   216591    Lightning Charging Cable                 1       14.95
# 185561   216592       AA Batteries (4-pack)                 1        3.84
# 185562   216593  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                         Purchase Address  \
# ...

# %%
df["Day"] = df["Order Date"].dt.day_name()

# %%
df["City2", "Region2"]= df["Purchase Address"].str.split(',', n=1, expand=True)
df["City2"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21696\2201120007.py in ?()
# ----> 1 df["City2", "Region2"]= df["Purchase Address"].str.split(',', n=1, expand=True)
#       2 df["City2"]
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3936             self._setitem_frame(key, value)
#    3937         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    3938             self._setitem_array(key, value)
#    3939         elif isinstance(value, DataFrame):
# -> 3940             self._set_item_frame_value(key, value)
#    3941         elif (
#    3942             is_list_like(value)
#    3943             and not self.columns.is_unique
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4090             self._set_item_mgr(key, arraylike)
# ...

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        294049    Lightning Charging Cable                 1       14.95
# 1        294050            Wired Headphones                 1       11.99
# 2        294051        USB-C Charging Cable                 2       11.95
# 3        294052            Wired Headphones                 1       11.99
# 4        294053            27in FHD Monitor                 1      149.99
# ...         ...                         ...               ...         ...
# 185558   216589  Bose SoundSport Headphones                 1       99.99
# 185559   216590            Wired Headphones                 1       11.99
# 185560   216591    Lightning Charging Cable                 1       14.95
# 185561   216592       AA Batteries (4-pack)                 1        3.84
# 185562   216593  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                         Purchase Address  \
# ...

# %%
# building a custom function to check orders after 7pm
df["Order Hour"] =  df["Order Date"].dt.hour
order_time = df["Order Hour"]
# print(order_time)
def LateHourPurchase(order):
    count
# Out:
# 0         19
# 1         18
# 2         16
# 3         13
# 4         21
#           ..
# 185558    21
# 185559     5
# 185560    18
# 185561    12
# 185562    19
# Name: Order Hour, Length: 184732, dtype: int32

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_region(address):
    return address.split(",")[2].split(" ")

# %%
df["City"] = df["Purchase Address"].apply(lambda x: f"{get_city(x)}, ({get_region(x)}) ")

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        294049    Lightning Charging Cable                 1       14.95
# 1        294050            Wired Headphones                 1       11.99
# 2        294051        USB-C Charging Cable                 2       11.95
# 3        294052            Wired Headphones                 1       11.99
# 4        294053            27in FHD Monitor                 1      149.99
# ...         ...                         ...               ...         ...
# 185558   216589  Bose SoundSport Headphones                 1       99.99
# 185559   216590            Wired Headphones                 1       11.99
# 185560   216591    Lightning Charging Cable                 1       14.95
# 185561   216592       AA Batteries (4-pack)                 1        3.84
# 185562   216593  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                         Purchase Address  \
# ...

# %% [markdown]
# #FILTRATION

# %%
df[df["Product"] == "Lightning Charging Cable"][["Product", "Price Each", "Order Date", "City"]]
# Out:
#                          Product  Price Each          Order Date  \
# 0       Lightning Charging Cable       14.95 2019-12-22 19:16:00
# 7       Lightning Charging Cable       14.95 2019-12-25 08:24:00
# 22      Lightning Charging Cable       14.95 2019-12-04 18:27:00
# 25      Lightning Charging Cable       14.95 2019-12-12 01:20:00
# 38      Lightning Charging Cable       14.95 2019-12-10 15:23:00
# ...                          ...         ...                 ...
# 185546  Lightning Charging Cable       14.95 2019-06-19 15:27:00
# 185548  Lightning Charging Cable       14.95 2019-06-25 08:23:00
# 185553  Lightning Charging Cable       14.95 2019-06-29 16:10:00
# 185556  Lightning Charging Cable       14.95 2019-06-18 22:15:00
# 185560  Lightning Charging Cable       14.95 2019-06-10 18:22:00
#
#                                       City
# 0           Kumasi, (['', 'AS', '40001'])
# 7           Tamale, (['', 'NR', '50301'])
# 22       Koforidua, (['', 'ER', '73301'])
# ...

# %%
df[df["Purchase Amount"]> 1000].head(25)
# Out:
#     Order ID             Product  Quantity Ordered  Price Each  \
# 99    294140  Macbook Pro Laptop                 1      1700.0
# 100   294141  Macbook Pro Laptop                 1      1700.0
# 210   294249  Macbook Pro Laptop                 1      1700.0
# 218   294257  Macbook Pro Laptop                 1      1700.0
# 222   294260  Macbook Pro Laptop                 1      1700.0
# 254   294291  Macbook Pro Laptop                 1      1700.0
# 299   294335  Macbook Pro Laptop                 1      1700.0
# 362   294394  Macbook Pro Laptop                 1      1700.0
# 385   294417  Macbook Pro Laptop                 1      1700.0
# 398   294429  Macbook Pro Laptop                 1      1700.0
# 417   294448  Macbook Pro Laptop                 1      1700.0
# 436   294465  Macbook Pro Laptop                 1      1700.0
# 447   294475  Macbook Pro Laptop                 1      1700.0
# 531   294555  Macbook Pro Laptop                 1      1700.0
# ...

# %%
df[df["Purchase Amount"]> 1000].sort_values(by = "Purchase Amount", ascending = False)
# Out:
#       Order ID             Product  Quantity Ordered  Price Each  \
# 3493    297370  Macbook Pro Laptop                 2      1700.0
# 22218   315237  Macbook Pro Laptop                 2      1700.0
# 96725   203816  Macbook Pro Laptop                 2      1700.0
# 34329   185369  Macbook Pro Laptop                 2      1700.0
# 41748   152414  Macbook Pro Laptop                 2      1700.0
# ...        ...                 ...               ...         ...
# 60749   170602        Google Phone                 2       600.0
# 50689   160963        Google Phone                 2       600.0
# 62886   172658        Google Phone                 2       600.0
# 22146   315167        Google Phone                 2       600.0
# 4517    298352        Google Phone                 2       600.0
#
#                Order Date                  Purchase Address  Purchase Amount  \
# 3493  2019-12-24 19:33:00  843 1st St, Cape Coast, CR 85001           3400.0
# ...
